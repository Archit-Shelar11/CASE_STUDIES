# %%
import pandas as pd
import numpy as np

# %%
df={
    'name':['Archit Shelar','Shrwan Kolekar'],
    'Branch' : ['Robotics and AI','Robotics and AI'],
    'Year':["TY",'TY']
}
df1=pd.DataFrame(df)
df1
# Out:
#              name           Branch Year
# 0   Archit Shelar  Robotics and AI   TY
# 1  Shrwan Kolekar  Robotics and AI   TY
